# %% [markdown]
# # Bike Accident Mapper

# %%
#import libraries
import pandas as pd
import numpy as np
import geopy
import matplotlib.pyplot as plt
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="Bike_Accidents")

# %%
#load data
df = pd.read_excel('bike_accidents.xlsx', encoding='WINDOWS-1255')
df.head()
# Out:
#   סוג פגיעה                תאריך   גיל אופניים רגילים או חשמליים  \
# 0       קשה  2018-07-16 00:00:00   NaN                   חשמליים
# 1      הרוג  2018-07-08 00:00:00   8.0                   אופניים
# 2    בינוני  2018-07-16 00:00:00   NaN                   אופניים
# 3    בינוני  2018-07-16 00:00:00  16.0                   חשמליים
# 4    בינוני  2018-07-13 00:00:00   8.0                   אופניים
#
#             מיקום  עיר או כביש  \
# 0    צומת בית דגן  ראשון לציון
# 1           סלעית        סלעית
# 2         הנביאים         חיפה
# 3  צומת קרית חיים          NaN
# 4           חניתה         חיפה
#
#                                                 לינק          כתובת מדוייק
# 0                  http://www.kolhazman.co.il/322936                   NaN
# 1  https://www.ynet.co.il/articles/0,7340,L-53065...                   NaN
# 2                    https://haipo.co.il/item/101660                   NaN
# 3                    https://haipo.co.il/item/101658                כביש 4
# 4                    https://haipo.co.il/item/101476  חניתה פינת טרומפלדור

# %%
df.iloc[:,3]

# %%
#Rebuild Table with english variables + new Variables
data = {"Date" : df['תאריך'],
       "Age" : df['גיל'],
       "Injury Type" : df['סוג פגיעה'],
       "Vehicle Type" : df.iloc[:,3],
        "Street" : df.iloc[:,5],
        "Detailed Street" : df.iloc[:,7],
        "City" : df.iloc[:,4],
        "Address" : "",
        "Link" : df.iloc[:,6],
        "location" : "",
        "lat" : "",
        "long" : ""
      }
df2 = pd.DataFrame.from_dict(data)

# %%
df2.head()
# Out:
#                   Date   Age Injury Type Vehicle Type       Street  \
# 0  2018-07-16 00:00:00   NaN         קשה      חשמליים  ראשון לציון
# 1  2018-07-08 00:00:00   8.0        הרוג      אופניים        סלעית
# 2  2018-07-16 00:00:00   NaN      בינוני      אופניים         חיפה
# 3  2018-07-16 00:00:00  16.0      בינוני      חשמליים          NaN
# 4  2018-07-13 00:00:00   8.0      בינוני      אופניים         חיפה
#
#              City Address      Detailed Address  \
# 0    צומת בית דגן                           NaN
# 1           סלעית                           NaN
# 2         הנביאים                           NaN
# 3  צומת קרית חיים                        כביש 4
# 4           חניתה          חניתה פינת טרומפלדור
#
#                                                 Link location lat long
# 0                  http://www.kolhazman.co.il/322936
# 1  https://www.ynet.co.il/articles/0,7340,L-53065...
# 2                    https://haipo.co.il/item/101660
# 3                    https://haipo.co.il/item/101658
# 4                    https://haipo.co.il/item/101476

# %%
df= df.rename(columns={"עיר או כביש": "location_heb", "מיקום" : "street_heb"})
df.head()
# Out:
#   סוג פגיעה                תאריך   גיל אופניים רגילים או חשמליים  \
# 0       קשה  2018-07-16 00:00:00   NaN                   חשמליים
# 1      הרוג  2018-07-08 00:00:00   8.0                   אופניים
# 2    בינוני  2018-07-16 00:00:00   NaN                   אופניים
# 3    בינוני  2018-07-16 00:00:00  16.0                   חשמליים
# 4    בינוני  2018-07-13 00:00:00   8.0                   אופניים
#
#        street_heb location_heb  \
# 0    צומת בית דגן  ראשון לציון
# 1           סלעית        סלעית
# 2         הנביאים         חיפה
# 3  צומת קרית חיים          NaN
# 4           חניתה         חיפה
#
#                                                 לינק          כתובת מדוייק  \
# 0                  http://www.kolhazman.co.il/322936                   NaN
# 1  https://www.ynet.co.il/articles/0,7340,L-53065...                   NaN
# 2                    https://haipo.co.il/item/101660                   NaN
# 3                    https://haipo.co.il/item/101658                כביש 4
# 4                    https://haipo.co.il/item/101476  חניתה פינת טרומפלדור
#
#   Address_heb
# 0
# 1
# 2
# 3
# 4

# %%
## fill Street/City NaN with blank
df2['Street'] = df2['Street'].fillna("")
df2['City'] = df2['City'].fillna("")

df2['Address'] = df2['Street'] + ", " + df2['City']

# %%
df2['Address'].head()
# Out:
# 0    ראשון לציון, צומת בית דגן
# 1                 סלעית, סלעית
# 2                חיפה, הנביאים
# 3             , צומת קרית חיים
# 4                  חיפה, חניתה
# Name: Address, dtype: object

# %%
#First attempt - fails on timeout
#df2['location'] = df['Address'].apply(geolocator.geocode)

# %%
#create empty lists for location, lat and long
locations = []
latitudes = []
longitudes = []

#iterate between each row in df2 and geocode location based on 'Address'
for index, row in df2.iterrows():
    address = row['Address']
    #print(address)
    location = geolocator.geocode(address, timeout=10)
    locations.append(location)
    print(location)
    #add long/lat
    if(location != None):
        #if location exists
        print(location.latitude,location.longitude)
        latitudes.append(location.latitude)
        longitudes.append(location.longitude)
    else:
        #if no location set default lat,long - 32,34
        print(32,34)
        latitudes.append(32)
        longitudes.append(34)
        
    
#print(locations)
# Out:
# צומת בית דגן, השבעה, נחלת יהודה, ראשון לציון, מחוז המרכז, NO, ישראל
# 32.002455 34.820515
# סלעית/יסעור, סלעית, ערד, מחוז הדרום, NO, ישראל
# 31.266409 35.21135
# הנביאים, חיפה, הדר הכרמל, חיפה, מחוז חיפה, NO, ישראל
# 32.8129956 34.995452
# צומת קרית חיים, שדרות ההסתדרות, קרית חיים, קריית חיים מזרחית, חיפה, מחוז חיפה, NO, ישראל
# 32.817155 35.076678
# חניתה, חיפה, נוה שאנן, חיפה, מחוז חיפה, NO, ישראל
# 32.7862429 35.0174697
# None
# 32 34
# האלוף עוזי נרקיס, קרית מנחם בגין, שועפט, ירושלים, מחוז ירושלים, NO
# 31.8209146 35.2335602
# אליהו בן חור, אם המושבות החדשה, פתח תקווה, מחוז המרכז, NO, ישראל
# 32.1075075 34.8765451
# ז'בוטינסקי, גבעת שמואל, רמת גן, מחוז תל אביב, NO, ישראל
# 32.0718863 34.8509527
# קרית אונו, 23, לוי אשכול, קריית אונו, מחוז תל אביב, NO, ישראל
# 32.0637716 34.8616367
# גניחובסקי, פרדס כץ, בני ברק, מחוז תל אביב, NO, ישראל
# 32.0990657 34.841524
# None
# 32 34
# מעבר בני ברית העצמאות, רובע ה', אשדוד, מחוז הדרום, NO, ישראל
# 31.7911515 34.6489388388525
# חיים עוזר, מרכז העיר, פתח תקווה, מחוז המרכז, NO, ישראל
# 32.0853546 34.8877248
# מחלף הסירה, דרך תל-אביב, הרצליה ב', הרצליה, מחוז תל אביב, NO, ישראל
# 32.159868 34.810438
# זאב ז'בוטינסקי, אזור התעשייה קריית אריה, פתח תקווה, מחוז המרכז, NO, ישראל
# 32.0926245 34.8469364
# זאב ז'בוטינסקי, תל גיבורים, בני ברק, מחוז תל אביב, NO, ישראל
# 32.0904386 34.82152
# לוינסקי, תל אביב - יפו, נווה שאנן, תל אביב-יפו, מחוז תל אביב, NO, ישראל
# 32.0569753 34.7790316
# פרויד, חיפה, רמת אשכול, חיפה, מחוז חיפה, NO, ישראל
# 32.7806039 34.9880739
# עודד, תל אביב - יפו, רמת גן, מחוז תל אביב, NO, ישראל
# 32.0563205 34.8112014
# עזרא, הר שלום, בני ברק, מחוז תל אביב, NO, ישראל
# 32.0799235 34.8388872
# מורדי הגטאות, רובע ב', אשדוד, מחוז הדרום, NO, ישראל
# 31.8055502 34.6584496
# יחזקאל, גני דן, ג'ואריש, רמלה, מחוז המרכז, NO, ישראל
# 31.9202081 34.8665292
# None
# 32 34
# None
# 32 34
# יפו, המשולש, מאה שערים, ירושלים, מחוז ירושלים, NO, ישראל
# 31.7819355 35.2198234
# יצחק בן צבי, קרית חיים, קריית חיים מזרחית, חיפה, מחוז חיפה, NO, ישראל
# 32.8182406 35.069054
# شبلي, מחוז הצפון, ישראל
# 32.6937221 35.3960008
# צומת בת הדר, 4, מועצה אזורית חוף אשקלון, מחוז הדרום, NO, ישראל
# 31.647126 34.594188
# צומת בת הדר, 4, מועצה אזורית חוף אשקלון, מחוז הדרום, NO, ישראל
# 31.647126 34.594188
# החשמונאים, נחל עשן (נווה מנחם), באר שבע, מחוז הדרום, NO, ישראל
# 31.2677458 34.7605595
# קיבוץ גלויות, רובע ב', אשדוד, מחוז הדרום, NO, ישראל
# 31.8014634 34.6505481
# None
# 32 34
# מחלף שעריה, כביש מכבית, גני הדר, פתח תקווה, מחוז המרכז, NO, ישראל
# 32.0672565 34.9110939
# חיבת ציון/הרא''ה, חיבת ציון, הלל, מרום נווה, רמת גן, מחוז תל אביב, NO, ישראל
# 32.079233 34.825057
# פינסקר / הברון הירש, פינסקר, קרול, פתח תקווה, מחוז המרכז, NO, ישראל
# 32.090754 34.884491
# לוד, מחוז המרכז, ישראל
# 31.9489012 34.8884857
# אלי כהן, אשכולי פז, אשקלון, מחוז הדרום, NO, ישראל
# 31.666406 34.5648758
# אם המושבות, אזור התעשייה קריית אריה, פתח תקווה, מחוז המרכז, NO, ישראל
# 32.1026101 34.863928
# הציונות, רובע הקריה, אשדוד, מחוז הדרום, NO, ישראל
# 31.7848825 34.6414328
# הציונות, רובע הקריה, אשדוד, מחוז הדרום, NO, ישראל
# 31.7848825 34.6414328
# אם המושבות, אזור התעשייה קריית אריה, פתח תקווה, מחוז המרכז, NO, ישראל
# 32.1026101 34.863928
# הציונות, רובע הקריה, אשדוד, מחוז הדרום, NO, ישראל
# 31.7848825 34.6414328
# רבי יוסף קארו, אלעד, מחוז המרכז, NO, ישראל
# 32.0489389 34.9652485
# سخنين, מחוז הצפון, ישראל
# 32.8638052 35.3023184
# רוקח, תל אביב - יפו, תל אביב-יפו, מחוז תל אביב, NO, ישראל
# 32.0951632 34.812633
# רוקח, תל אביב - יפו, תל אביב-יפו, מחוז תל אביב, NO, ישראל
# 32.0951632 34.812633
# בלפור, בת ים, שיכון ותיקים, בת ים, מחוז תל אביב, NO, ישראל
# 32.0224339 34.7454766
# הרב אהרונסון/דוד פנקס, אהרונסון, הר שלום, בני ברק, מחוז תל אביב, NO, ישראל
# 32.081032 34.827542
# None
# 32 34

# %%
#update table with geocoded location, lat and long
df2['location'] = locations
df2['lat'] = latitudes
df2['long'] = longitudes

# %%
df2
# Out:
#                    Date   Age    Injury Type      Vehicle Type       Street  \
# 0   2018-07-16 00:00:00   NaN            קשה           חשמליים  ראשון לציון
# 41           17/09/2018  30.0            קשה   אופניים חשמליים    פתח תקווה
# 42           20/09/2018  15.0         בינוני   אופניים חשמליים        אשדוד
# 43           22/09/2018  11.0         בינוני   אופניים חשמליים         אלעד
# 44           24/09/2018  16.0         בינוני           אופניים       סח'נין
# 45           24/09/2018  16.0           הרוג   אופניים חשמליים      תל אביב
# 46           24/09/2018  16.0         בינוני   אופניים חשמליים      תל אביב
# 47           27/09/2018  17.0             קל   אופניים חשמליים        בת ים
# 48           27/09/2018  21.0         בינוני   אופניים חשמליים      בני ברק
# 49           28/09/2018  30.0            קשה           אופניים   אפרת-אלעזר
#
#                 City                    Address  \
# 0       צומת בית דגן  ראשון לציון, צומת בית דגן
# 1              סלעית               סלעית, סלעית
# 2            הנביאים              חיפה, הנביאים
# 3     צומת קרית חיים           , צומת קרית חיים
# 4              חניתה                חיפה, חניתה
# 5      מחלף ראש העין      כביש 5, מחלף ראש העין
# 6         עוזי נרקיס        ירושלים, עוזי נרקיס
# 7             בן חור          פתח תקווה, בן חור
# 8         ז'בוטינסקי         רמת גן, ז'בוטינסקי
# 9          לוי אשכול       קרית אונו, לוי אשכול
# 10         גניחובסקי         בני ברק, גניחובסקי
# 11         צבי נוימן         ירושלים, צבי נוימן
# 12          בני ברית            אשדוד, בני ברית
# 13         חיים עוזר       פתח תקווה, חיים עוזר
# 14        מחלף הסירה         הרצליה, מחלף הסירה
# 15        ז'בוטינסקי      פתח תקווה, ז'בוטינסקי
# 16        ז'בוטינסקי        בני ברק, ז'בוטינסקי
# 17           לוינסקי           תל אביב, לוינסקי
# 18             פרויד                חיפה, פרויד
# 19              עודד               רמת גן, עודד
# 20              עזרא              בני ברק, עזרא
# 21      מורדי הגטאות        אשדוד, מורדי הגטאות
# 22            יחזקאל               רמלה, יחזקאל
# 23       עובד בן עמי         אשדוד, עובד בן עמי
# 24  צומת נאות אשקלון   אשקלון, צומת נאות אשקלון
# 25           ירושלים               יפו, ירושלים
# 26       יצחק בן צבי          חיפה, יצחק בן צבי
# 27              שבלי                 שבלי, שבלי
# 28       צומת בת הדר        אשקלון, צומת בת הדר
# 29       צומת בת הדר        אשקלון, צומת בת הדר
# 30         החשמונאים         באר שבע, החשמונאים
# 31      קיבוץ גלויות        אשדוד, קיבוץ גלויות
# 32     מחלף רמלה לוד         לוד, מחלף רמלה לוד
# 33        מחלף שעריה      פתח תקווה, מחלף שעריה
# 34              הראה               רמת גן, הראה
# 35        הברון הירש      פתח תקווה, הברון הירש
# 36                                        לוד,
# 37           אלי כהן            אשקלון, אלי כהן
# 38        אם המושבות      פתח תקווה, אם המושבות
# 39           הציונות             אשדוד, הציונות
# 40           הציונות             אשדוד, הציונות
# 41        אם המושבות      פתח תקווה, אם המושבות
# 42           הציונות             אשדוד, הציונות
# 43         יוסף קארו            אלעד, יוסף קארו
# 44                                     סח'נין,
# 45              רוקח              תל אביב, רוקח
# 46              רוקח              תל אביב, רוקח
# 47             בלפור               בת ים, בלפור
# 48      הרב אהרונסון      בני ברק, הרב אהרונסון
# 49           כביש 60        אפרת-אלעזר, כביש 60
#
#                         Detailed Address  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                 כביש 4
# 4                   חניתה פינת טרומפלדור
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 
# 49  http://www.maariv.co.il/breaking-news/Article-...
#
#                                              location        lat       long
# 0   (צומת בית דגן, השבעה, נחלת יהודה, ראשון לציון,...  32.002455  34.820515
# 1   (סלעית/יסעור, סלעית, ערד, מחוז הדרום, NO, ישרא...  31.266409  35.211350
# 2   (הנביאים, חיפה, הדר הכרמל, חיפה, מחוז חיפה, NO...  32.812996  34.995452
# 3   (צומת קרית חיים, שדרות ההסתדרות, קרית חיים, קר...  32.817155  35.076678
# 4   (חניתה, חיפה, נוה שאנן, חיפה, מחוז חיפה, NO, י...  32.786243  35.017470
# 5                                                None  32.000000  34.000000
# 6   (האלוף עוזי נרקיס, קרית מנחם בגין, שועפט, ירוש...  31.820915  35.233560
# 7   (אליהו בן חור, אם המושבות החדשה, פתח תקווה, מח...  32.107507  34.876545
# 8   (ז'בוטינסקי, גבעת שמואל, רמת גן, מחוז תל אביב,...  32.071886  34.850953
# 9   (קרית אונו, 23, לוי אשכול, קריית אונו, מחוז תל...  32.063772  34.861637
# 10  (גניחובסקי, פרדס כץ, בני ברק, מחוז תל אביב, NO...  32.099066  34.841524
# 11                                               None  32.000000  34.000000
# 12  (מעבר בני ברית העצמאות, רובע ה', אשדוד, מחוז ה...  31.791152  34.648939
# 13  (חיים עוזר, מרכז העיר, פתח תקווה, מחוז המרכז, ...  32.085355  34.887725
# 14  (מחלף הסירה, דרך תל-אביב, הרצליה ב', הרצליה, מ...  32.159868  34.810438
# 15  (זאב ז'בוטינסקי, אזור התעשייה קריית אריה, פתח ...  32.092624  34.846936
# 16  (זאב ז'בוטינסקי, תל גיבורים, בני ברק, מחוז תל ...  32.090439  34.821520
# 17  (לוינסקי, תל אביב - יפו, נווה שאנן, תל אביב-יפ...  32.056975  34.779032
# 18  (פרויד, חיפה, רמת אשכול, חיפה, מחוז חיפה, NO, ...  32.780604  34.988074
# 19  (עודד, תל אביב - יפו, רמת גן, מחוז תל אביב, NO...  32.056320  34.811201
# 20  (עזרא, הר שלום, בני ברק, מחוז תל אביב, NO, ישר...  32.079923  34.838887
# 21  (מורדי הגטאות, רובע ב', אשדוד, מחוז הדרום, NO,...  31.805550  34.658450
# 22  (יחזקאל, גני דן, ג'ואריש, רמלה, מחוז המרכז, NO...  31.920208  34.866529
# 23                                               None  32.000000  34.000000
# 24                                               None  32.000000  34.000000
# 25  (יפו, המשולש, מאה שערים, ירושלים, מחוז ירושלים...  31.781935  35.219823
# 26  (יצחק בן צבי, קרית חיים, קריית חיים מזרחית, חי...  32.818241  35.069054
# 27  (شبلي, מחוז הצפון, ישראל, (32.6937221, 35.3960...  32.693722  35.396001
# 28  (צומת בת הדר, 4, מועצה אזורית חוף אשקלון, מחוז...  31.647126  34.594188
# 29  (צומת בת הדר, 4, מועצה אזורית חוף אשקלון, מחוז...  31.647126  34.594188
# 30  (החשמונאים, נחל עשן (נווה מנחם), באר שבע, מחוז...  31.267746  34.760559
# 31  (קיבוץ גלויות, רובע ב', אשדוד, מחוז הדרום, NO,...  31.801463  34.650548
# 32                                               None  32.000000  34.000000
# 33  (מחלף שעריה, כביש מכבית, גני הדר, פתח תקווה, מ...  32.067256  34.911094
# 34  (חיבת ציון/הרא''ה, חיבת ציון, הלל, מרום נווה, ...  32.079233  34.825057
# 35  (פינסקר / הברון הירש, פינסקר, קרול, פתח תקווה,...  32.090754  34.884491
# 36  (לוד, מחוז המרכז, ישראל, (31.9489012, 34.88848...  31.948901  34.888486
# 37  (אלי כהן, אשכולי פז, אשקלון, מחוז הדרום, NO, י...  31.666406  34.564876
# 38  (אם המושבות, אזור התעשייה קריית אריה, פתח תקוו...  32.102610  34.863928
# 39  (הציונות, רובע הקריה, אשדוד, מחוז הדרום, NO, י...  31.784882  34.641433
# 40  (הציונות, רובע הקריה, אשדוד, מחוז הדרום, NO, י...  31.784882  34.641433
# 41  (אם המושבות, אזור התעשייה קריית אריה, פתח תקוו...  32.102610  34.863928
# 42  (הציונות, רובע הקריה, אשדוד, מחוז הדרום, NO, י...  31.784882  34.641433
# 43  (רבי יוסף קארו, אלעד, מחוז המרכז, NO, ישראל, (...  32.048939  34.965249
# 44  (سخنين, מחוז הצפון, ישראל, (32.8638052, 35.302...  32.863805  35.302318
# 45  (רוקח, תל אביב - יפו, תל אביב-יפו, מחוז תל אבי...  32.095163  34.812633
# 46  (רוקח, תל אביב - יפו, תל אביב-יפו, מחוז תל אבי...  32.095163  34.812633
# 47  (בלפור, בת ים, שיכון ותיקים, בת ים, מחוז תל אב...  32.022434  34.745477
# 48  (הרב אהרונסון/דוד פנקס, אהרונסון, הר שלום, בני...  32.081032  34.827542
# 49                                               None  32.000000  34.000000

# %%
accidentByAge = df2.groupby('Age').size().reset_index(name='count')

# %%
accidentByAge['count'].sum()
# Out:
# 48

# %%
accidentByAge.hist(column='count')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B54243C978>]],
#       dtype=object)

# %%
accidentByAge.plot.bar(x='Age', y='count')

# %%
accidentByInjury = df2.groupby('Injury Type').size().reset_index(name='count')
accidentByInjury

# %%
accidentByInjuryAge = df2.groupby(['Injury Type', 'Age']).size().reset_index(name='count')
accidentByInjuryAge
# Out:
#       Injury Type   Age  count
# 0            אנוש  30.0      1
# 1            אנוש  50.0      1
# 2          בינוני   8.0      2
# 3          בינוני  11.0      1
# 4          בינוני  12.0      1
# 5          בינוני  13.0      2
# 6          בינוני  14.0      2
# 7          בינוני  15.0      4
# 8          בינוני  16.0      4
# 9          בינוני  17.0      1
# 10         בינוני  18.0      1
# 11         בינוני  21.0      1
# 12         בינוני  26.0      1
# 13         בינוני  31.0      1
# 14         בינוני  40.0      1
# 15         בינוני  50.0      1
# 16         בינוני  54.0      1
# 17  בינוני עד קשה  16.0      1
# 18     בינוני-קשה  17.0      1
# 19           הרוג   8.0      1
# 20           הרוג  16.0      2
# 21           הרוג  20.0      1
# 22           הרוג  27.0      1
# 23           הרוג  35.0      1
# 24           הרוג  50.0      1
# 25           הרוג  60.0      1
# 26             קל   8.0      1
# 27             קל  17.0      1
# 28             קל  42.0      1
# 29             קל  55.0      1
# 30            קשה  14.0      1
# 31            קשה  16.0      1
# 32            קשה  25.0      1
# 33            קשה  30.0      3
# 34            קשה  40.0      1
# 35            קשה  63.0      1

# %%
accidentByInjury.plot.bar(x='Injury Type')

# %%
#accidentByAge = accidentByAge.set_index('Age')
x = accidentByAge['Age']

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-a8c5aab98709> in <module>()
#       1 plt.figure()
# ----> 2 x.bar()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'bar'

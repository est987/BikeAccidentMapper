# %%
import pandas as pd
import numpy as np
import geopy

# %%
df = pd.read_excel('bike_accidents.xlsx', encoding='WINDOWS-1255')

# %%
df.head()
# Out:
#   סוג פגיעה                תאריך   גיל אופניים רגילים או חשמליים  \
# 0       קשה  2018-07-16 00:00:00   NaN                   חשמליים
# 1      הרוג  2018-07-08 00:00:00   8.0                   אופניים
# 2    בינוני  2018-07-16 00:00:00   NaN                   אופניים
# 3    בינוני  2018-07-16 00:00:00  16.0                   חשמליים
# 4    בינוני  2018-07-13 00:00:00   8.0                   אופניים
#
#                   street_heb location_heb  \
# 0               צומת בית דגן  ראשון לציון
# 1                      סלעית        סלעית
# 2               רחוב הנביאים         חיפה
# 3             צומת קרית חיים       כביש 4
# 4  רחוב חניתה פינת טרומפלדור         חיפה
#
#                                                 לינק Address_heb
# 0                  http://www.kolhazman.co.il/322936
# 1  https://www.ynet.co.il/articles/0,7340,L-53065...
# 2                    https://haipo.co.il/item/101660
# 3                    https://haipo.co.il/item/101658
# ...

# %%
df['Address_heb'] = ""

# %%
df= df.rename(columns={"עיר או כביש": "location_heb", "מיקום" : "street_heb"})
df.head()
# Out:
#   סוג פגיעה                תאריך   גיל אופניים רגילים או חשמליים  \
# 0       קשה  2018-07-16 00:00:00   NaN                   חשמליים
# 1      הרוג  2018-07-08 00:00:00   8.0                   אופניים
# 2    בינוני  2018-07-16 00:00:00   NaN                   אופניים
# 3    בינוני  2018-07-16 00:00:00  16.0                   חשמליים
# 4    בינוני  2018-07-13 00:00:00   8.0                   אופניים
#
#                   street_heb location_heb  \
# 0               צומת בית דגן  ראשון לציון
# 1                      סלעית        סלעית
# 2               רחוב הנביאים         חיפה
# 3             צומת קרית חיים       כביש 4
# 4  רחוב חניתה פינת טרומפלדור         חיפה
#
#                                                 לינק Address_heb
# 0                  http://www.kolhazman.co.il/322936
# 1  https://www.ynet.co.il/articles/0,7340,L-53065...
# 2                    https://haipo.co.il/item/101660
# 3                    https://haipo.co.il/item/101658
# ...

# %%
df['Address_heb'] = df['street_heb'] + ", " + df['location_heb']
df['nominatum_loc'] = ""
df['lat'] = ""

# %%
df.head()
# Out:
#   סוג פגיעה                תאריך   גיל אופניים רגילים או חשמליים  \
# 0       קשה  2018-07-16 00:00:00   NaN                   חשמליים
# 1      הרוג  2018-07-08 00:00:00   8.0                   אופניים
# 2    בינוני  2018-07-16 00:00:00   NaN                   אופניים
# 3    בינוני  2018-07-16 00:00:00  16.0                   חשמליים
# 4    בינוני  2018-07-13 00:00:00   8.0                   אופניים
#
#                   street_heb location_heb  \
# 0               צומת בית דגן  ראשון לציון
# 1                      סלעית        סלעית
# 2               רחוב הנביאים         חיפה
# 3             צומת קרית חיים       כביש 4
# 4  רחוב חניתה פינת טרומפלדור         חיפה
#
#                                                 לינק  \
# 0                  http://www.kolhazman.co.il/322936
# 1  https://www.ynet.co.il/articles/0,7340,L-53065...
# 2                    https://haipo.co.il/item/101660
# 3                    https://haipo.co.il/item/101658
# ...

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="Bike_Accidents")

# %%
df['nominatum_loc'] = df['Address_heb'].apply(geolocator.geocode)

# %%
df.head(30)
# Out:
#         סוג פגיעה                תאריך   גיל אופניים רגילים או חשמליים  \
# 0             קשה  2018-07-16 00:00:00   NaN                   חשמליים
# 1            הרוג  2018-07-08 00:00:00   8.0                   אופניים
# 2          בינוני  2018-07-16 00:00:00   NaN                   אופניים
# 3          בינוני  2018-07-16 00:00:00  16.0                   חשמליים
# 4          בינוני  2018-07-13 00:00:00   8.0                   אופניים
# 5            אנוש  2018-07-06 00:00:00  50.0                   אופניים
# 6            הרוג  2018-07-07 00:00:00  27.0           אופניים חשמליים
# 7   בינוני עד קשה  2018-07-05 00:00:00  16.0                   חשמליים
# 8             קשה  2018-07-23 00:00:00  63.0                   חשמליים
# 9          בינוני  2018-07-25 00:00:00  54.0                   חשמליים
# 10         בינוני  2018-07-26 00:00:00  13.0                   חשמליים
# 11         בינוני  2018-07-29 00:00:00  40.0                   חשמליים
# ...

# %%
for index, row in df.iterrows():
    
    result = pd.concat(row['location_heb'],row['street_heb'])
    print (result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-01d321dc5c95> in <module>()
#       1
# ----> 2 for index, row in df.iterrow():
#       3     row['nominatum_loc'] = row['Address_heb'].apply(geolocator.geocode)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'iterrow'

# %%
    row['Address_heb'] = row['location_heb'], ",", row['street_heb'])
